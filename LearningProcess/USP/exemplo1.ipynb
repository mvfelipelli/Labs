# %% [markdown]
# # Exercício 1
#
# Qual é o gênero mais frequente?
#
# E a faixa de idade?

# %%
#from google.colab import drive
#drive.mount('/content/drive')

import pandas as pd
df = pd.read_csv('datasets/teste_aplicativo.csv')
df.head()
# Out:
#    Unnamed: 0  idpessoa   faixa_idade            genero  \
# 0           0         1  jovem adulto             homem
# 1           1         2        adulto             homem
# 2           2         3        adulto  não identificado
# 3           3         4         jovem            mulher
# 4           4         5         jovem             homem
#
#    Aplicativo Minimalista  Aplicativo Completo
# 0                       1                    0
# 1                       0                    1
# 2                       1                    0
# 3                       1                    0
# 4                       1                    0

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df.head()
# Out:
#    idpessoa   faixa_idade            genero  Aplicativo Minimalista  \
# 0         1  jovem adulto             homem                       1
# 1         2        adulto             homem                       0
# 2         3        adulto  não identificado                       1
# 3         4         jovem            mulher                       1
# 4         5         jovem             homem                       1
#
#    Aplicativo Completo
# 0                    0
# 1                    1
# 2                    0
# 3                    0
# 4                    0
